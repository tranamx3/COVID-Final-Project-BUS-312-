# %% [markdown]
# # COVID FINAL PROJECT
# #### By Chi Nam Tran, Aileen Zaman, Nathacia Nathacia, Sophia Van Den Ende, Shruti Lakhani and Justin Vu

# %% [markdown]
# ## COVID-19 Background
#
# Since December 2019, COVID-19 disease (commonly labelled as the coronavirus or covid) <img src="main_928px.jpg"
#      align="right"
#      width="150"/>  is an infectous disease caused by SARS-CoV-2 virus. The coronavirus can be spread from person to person (WHO, 2023). The virus can spread from an infected person’s mouth or nose in small liquid particles when they cough, sneeze, speak, sing or breathe. As of  January 15, 2023 the total cases of covid 19 is 671,323,775 with 6,730,373 deaths and 642,409,943 recovered within the total cases (worldometer, 2020). It has infected over 229 countries with it being in its 4th major variant (Omicron). It can be diagnosed through viral with two main types of viral tests being nucleic acid amplification tests (NAATs) and antigen tests (CDC, 2022). Since Dec. 11, 2020, there have been international releases of the covid vaccine which has saved many lives from the pandemic (as aforementioned 642,409,943 recovery).
# </div>
# <p style='text-align: right;' size='10;'> *Illustration of Covid-19 </p>
# </div>

# %% [markdown]
# #### Introduction & Purpose of Project
#
# Our group aims to understand better of covid-19 and it's affect on the United States in the different states. We'll look at the datasets that looks at the states records of covid cases and vaccinations.
# For the first half explores and analyzes the datasets independently and draw interpretations from it. The second half will merges both datasets to see any correlation and make conclusions.
#
# The datasets we'll be looking into are will be "all-states-history.csv" from https://covidtracking.com/data on the states records of covid cases. The second dataset we'll look at is ""us_state_vaccinations.csv" from "https://www.nature.com/articles/s41562-021-01122-8" which looks at vaccination records from covid-19 cases.
#
#
#
#
# ## I. Data Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Importing pandas to access analytical tools
#Importing seaborn to create statistical graphs

# %%
df=pd.read_csv("all-states-history.csv")
df
# Out:
#              date state    death  deathConfirmed  deathIncrease  \
# 0      2021-03-07    AK    305.0             NaN              0
# 1      2021-03-07    AL  10148.0          7963.0             -1
# 2      2021-03-07    AR   5319.0          4308.0             22
# 3      2021-03-07    AS      0.0             NaN              0
# 4      2021-03-07    AZ  16328.0         14403.0              5
# ...           ...   ...      ...             ...            ...
# 20775  2020-01-17    WA      NaN             NaN              0
# 20776  2020-01-16    WA      NaN             NaN              0
# 20777  2020-01-15    WA      NaN             NaN              0
# 20778  2020-01-14    WA      NaN             NaN              0
# 20779  2020-01-13    WA      NaN             NaN              0
#
#        deathProbable  hospitalized  hospitalizedCumulative  \
# 0                NaN        1293.0                  1293.0
# 1             2185.0       45976.0                 45976.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20780 entries, 0 to 20779
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date                              20780 non-null  object
#  1   state                             20780 non-null  object
#  2   death                             19930 non-null  float64
#  3   deathConfirmed                    9422 non-null   float64
#  4   deathIncrease                     20780 non-null  int64
#  5   deathProbable                     7593 non-null   float64
#  6   hospitalized                      12382 non-null  float64
#  7   hospitalizedCumulative            12382 non-null  float64
#  8   hospitalizedCurrently             17339 non-null  float64
#  9   hospitalizedIncrease              20780 non-null  int64
#  10  inIcuCumulative                   3789 non-null   float64
# ...

# %% [markdown]
# #### ^ The input above shows this dataset contains 40 variables with 20780 entities. We can also see that there are many missing values as indicated by the null value, "NaN".

# %%
df.isnull().sum()
# Out:
# date                                    0
# state                                   0
# death                                 850
# deathConfirmed                      11358
# deathIncrease                           0
# deathProbable                       13187
# hospitalized                         8398
# hospitalizedCumulative               8398
# hospitalizedCurrently                3441
# hospitalizedIncrease                    0
# inIcuCumulative                     16991
# inIcuCurrently                       9144
# negative                             7490
# negativeIncrease                        0
# negativeTestsAntibody               19322
# negativeTestsPeopleAntibody         19808
# negativeTestsViral                  15756
# onVentilatorCumulative              19490
# onVentilatorCurrently               11654
# positive                              188
# positiveCasesViral                   6534
# positiveIncrease                        0
# ...

# %% [markdown]
# #### ^ The input gives back the number of null/missing value in the dataset.

# %%
df.fillna(0)
# Out:
#              date state    death  deathConfirmed  deathIncrease  \
# 0      2021-03-07    AK    305.0             0.0              0
# 1      2021-03-07    AL  10148.0          7963.0             -1
# 2      2021-03-07    AR   5319.0          4308.0             22
# 3      2021-03-07    AS      0.0             0.0              0
# 4      2021-03-07    AZ  16328.0         14403.0              5
# ...           ...   ...      ...             ...            ...
# 20775  2020-01-17    WA      0.0             0.0              0
# 20776  2020-01-16    WA      0.0             0.0              0
# 20777  2020-01-15    WA      0.0             0.0              0
# 20778  2020-01-14    WA      0.0             0.0              0
# 20779  2020-01-13    WA      0.0             0.0              0
#
#        deathProbable  hospitalized  hospitalizedCumulative  \
# 0                0.0        1293.0                  1293.0
# 1             2185.0       45976.0                 45976.0
# ...

# %% [markdown]
# ####  ^ This code replaces the null/missing values to make the dataset more accurate.

# %%
df = df.bfill()

# %% [markdown]
# #### ^ An additional code (backwards filling) is inputted since some negative value shows null values. This can be because some values in the negative and recovered column are blank hence the result from the table below shows that some state values are null.

# %% [markdown]
# ## II(a). Data Exploration: Data Tabling
# We made tables to display the statistics numerically and orderly.

# %%
dv=df[['state','death','positive', 'negative', 'recovered']].groupby('state').max()
dv
# Out:
#          death   positive    negative  recovered
# state
# AK       305.0    56886.0   1931711.0   295690.0
# AL     10149.0   499819.0   1931711.0   295690.0
# AR      5417.0   324818.0   2480716.0   315517.0
# AS         0.0     1157.0     15602.0    29570.0
# AZ     16328.0   826454.0   3073010.0    29570.0
# CA     54124.0  3501394.0   2199458.0    29570.0
# CO      5989.0   436602.0   2199458.0    29570.0
# CT      7704.0   285330.0    545070.0    29570.0
# DC      1030.0    41419.0    545070.0    29570.0
# DE      1473.0    88354.0    545070.0    18851.0
# FL     32266.0  1909209.0   9339038.0     7590.0
# GA     17906.0  1023487.0    112887.0     7590.0
# GU       133.0     7749.0    112887.0     7590.0
# HI       445.0    28699.0   1044418.0   320054.0
# IA      5558.0   282384.0   1044418.0   320054.0
# ID      1879.0   172931.0    505964.0    96017.0
# IL     23014.0  1198335.0   2483156.0    48145.0
# IN     12737.0   667262.0   2483156.0    48145.0
# ...

# %% [markdown]
# #### ^ This input helps to group the individual entries by states which is a variable. Since there are many variables we wanted to specifically look at "death","positive" and "negative".

# %%
dv.nlargest(n=3, columns=['positive','negative','recovered'])
# Out:
#          death   positive   negative  recovered
# state
# CA     54124.0  3501394.0  2199458.0    29570.0
# TX     44451.0  2686818.0  1560293.0  2502609.0
# FL     32266.0  1909209.0  9339038.0     7590.0

# %% [markdown]
# #### ^ This input returns the table with three states that have the largest number by "positive" cases.

# %%
dv.nsmallest(n=3, columns=['positive','negative','recovered'])
# Out:
#        death  positive  negative  recovered
# state
# MP       2.0     145.0   17429.0      233.0
# AS       0.0    1157.0   15602.0    29570.0
# VI      92.0    2714.0   46167.0     2559.0

# %% [markdown]
# #### ^ This input returns the table with three states that have the smallest number by "positive" cases.

# %%
data=df[df['state'].isin(['CA','TX','FL','AS','MP','VI'])]

# %% [markdown]
# ## II(b). Data Exploration: Data Graphs for Covid Cases
#
# We'll be looking more in depth on the dataset for "all-states-history.csv" and see any correlation witin it's variables.

# %%
x = data['death']
y = data['positive']

# %%
data.plot(kind ="scatter", x= 'death', y ='positive', c = 'steelblue')
plt.title("Positive cases from the 3 biggest and smallest states by cases")
plt.rcParams['figure.figsize'] = [20, 10]
#plt.rcParams sets all graphs by 20:10

# %%
sns.lmplot(x='death', y ='positive', data=data,)
plt.title("Positive cases by the 3 biggest and smallest states")
sns.set(rc={'figure.figsize':(20,10)})
#sns.set sets all graphs by 20:10

# %% [markdown]
# #### ^ The two graphs above show the correlation between the variable "death" and "positive" cases. Although it seems as though there are trendlines from the scatterplot points, it's arranging by the values that are related to each state. The second graph shows the trendline along the scatterplot showing that there is a positive correlation between death and positive cases. The graph shows that the three states with the largest count overwhelmingly shadows the three states with the smallest count. It should be noted as well that although it's not shown the scatterplot is able to expand is because of the different date entries.

# %%
g=sns.regplot(x="negative",y="positive", data=df)
g.set(xlim=80, ylim=60, title="negative vs. postive")
# Out:
# [(80.0, 10696288.05),
#  (60.0, 3676463.7),
#  Text(0.5, 1.0, 'negative vs. postive')]

# %% [markdown]
# #### ^ We decided to plot against positive and negative cases with all the states under the scatterplot. Although it's hard to tell it shows that states with more positive cases have less negative cases whereas states with higher negative cases have less postive cases. The trendline in the graph shows a steady positive correlation between negative and positive cases however it should be emphasized that it doesn't reflect that a person who have a negative case will have a positive case.

# %%
g=sns.relplot(x="negative", y="positive", data=df, hue="state")
g.set(xlim=80, ylim=60, title="negative vs. postive")
# g.set(title="Age vs. Fare", xlim=[0,80], ylim=[0,600])

# %% [markdown]
# #### ^ This graph compliments with the first one as it color codes all the states by hue which makes it more identifiable. We can see that California and Texas have more positive cases than negative cases. Interestingly Florida seems to have a steady increase in both negative and positive cases.

# %%
g=sns.relplot(x="recovered", y="positive", data=df, hue="state")
g.set(xlim=80, ylim=60, title="recovered vs. postive")

# %% [markdown]
# #### ^ Additionally we made a scatterplot to see the relation between positive and recovered cases between the states. Unsurprisingly California still set the highest in positive cases with very low recovered cases however Texas again have a steady increase in both recovered and positive cases.

# %%
#number of positive cases 
import seaborn as spu
spu.histplot(data=df, x = "state", y = "positive", hue = "state")
# Out:
# <AxesSubplot:xlabel='state', ylabel='positive'>

# %% [markdown]
# #### ^ The graph above shows the all the state's number by positive cases in a histogram. We can see again the three states California, Texas and Florida having the largest numbers.

# %%
#bar chart
#Creating bar plot
sns.barplot(x = 'positive',y = 'state',data = df ,palette = "rainbow")
#Adding the aesthetics
plt.title('number of cases')
plt.xlabel('hospitalized')
plt.ylabel('state') 
# Show the plot
plt.show()

# %% [markdown]
# #### ^ We also wanted to see if there are any variation in the value of "hospitalized" cases but unsurprisingly the number of cases correlates strongly with the number of states with higher positive cases.

# %%
plt.hist(df.loc[df["state"]=='CA', "positive"],bins=range(0,90,10),  color = 'lightgreen')
plt.hist(df.loc[df["state"]=='FL', "positive"], bins=range(0,90,10), color=  'lightblue')
plt.hist(df.loc[df["state"]=='TX', "positive"], bins=range(0,90,10), color=  'crimson')
plt.title("positive cases comparison between CA & TX")
plt.margins(x=0,y=0)
#plt.ylim([0,70])
#plt.yticks(range(0,75,10))
plt.xlim([0,80])
plt.legend(["positive cases in CA","positive cases in FL","positive cases in TX"],loc="upper left")
plt.xlabel('date')
plt.ylabel('number of positive cases (in thousands)') 
plt.savefig("age.jpg")

# %% [markdown]
# #### ^ We also made histogram using boolen method marked down by the three states with the highest positive cases by its date. Although the graph shows the numbers for all three states we're unsure of why there are some missing values in the column and suspect that it can be due to the data filtering process eliminating some of the data points. The graph here does show that California still has an overwhelming number of cases compared to the other two highest states.

# %% [markdown]
# ## COVID-19 Vaccination Background
#
# Fortunately we have been able to combat covid-19 with vaccinations which has saved millions of lives. Accordign to the CDC, there are 4 approved vaccines in the US. These are:
#
#    <img src="Covid-19_vaccination_record_card_with_vials_and_syringe_yzliat.jpeg"
#      align="right"
#      width="175"/>
#
#     1. Pfizer-BioNTech COVID-19 vaccine
#     2. Moderna COVID-19 vaccine
#     3. Johnson & Johnson's Janssen COVID-19 vaccine
#     4. Novavax COVID-19 vaccine
# (CDC, 2022)
#
# As of 2022 more than 900 million doses have been released across all 50 states of the United States.
# The initial release of the covid-19 vaccines as well as it's protocols to mantain infection was made with backlash and negligence from the public the US. Causes of backlash stem from socieconomic to political factors however most of the public was able to catch on the severity of the pandemic's transmissive.

# %% [markdown]
# ## III. Data Merging
#
# We'll merge both datasdets "all-states-history.csv" and "us_state_vaccinations.csv" to make correlation interpretation of covid cases and vaccination records between the states.

# %%
df1=pd.read_csv("us_state_vaccinations.csv")

# %%
#step 1
df1=df1.rename(columns={"location":"state"})
df1
# Out:
#              date    state  total_vaccinations  total_distributed  \
# 0      2021-01-12  Alabama             78134.0           377025.0
# 1      2021-01-13  Alabama             84040.0           378975.0
# 2      2021-01-14  Alabama             92300.0           435350.0
# 3      2021-01-15  Alabama            100567.0           444650.0
# 4      2021-01-16  Alabama                 NaN                NaN
# ...           ...      ...                 ...                ...
# 47007  2023-01-07  Wyoming                 NaN                NaN
# 47008  2023-01-08  Wyoming                 NaN                NaN
# 47009  2023-01-09  Wyoming                 NaN                NaN
# 47010  2023-01-10  Wyoming                 NaN                NaN
# 47011  2023-01-11  Wyoming            847156.0          1246855.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0                70861.0                                 0.15
# ...

# %% [markdown]
# #### ^In order to merge both dataset we need to find the primary key in the dataset "us_state_vaccinations".  Once we've identified the key being "location" and "date", we have to rename the pk "location" to "state" so that it matches with other primary key from the dataset "all-states-history.csv" this will allow us to merge both dataset together.

# %%
#step 2
df1=df1.replace({"California":"CA",
              "Texas":"TX","Arizona":"AZ","Alabama":"AL","Florida":"FL",
                "Colorado":"CO","New York":"NY","Hawaii":"HI"})
df1
# Out:
#              date    state  total_vaccinations  total_distributed  \
# 0      2021-01-12       AL             78134.0           377025.0
# 1      2021-01-13       AL             84040.0           378975.0
# 2      2021-01-14       AL             92300.0           435350.0
# 3      2021-01-15       AL            100567.0           444650.0
# 4      2021-01-16       AL                 NaN                NaN
# ...           ...      ...                 ...                ...
# 47007  2023-01-07  Wyoming                 NaN                NaN
# 47008  2023-01-08  Wyoming                 NaN                NaN
# 47009  2023-01-09  Wyoming                 NaN                NaN
# 47010  2023-01-10  Wyoming                 NaN                NaN
# 47011  2023-01-11  Wyoming            847156.0          1246855.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0                70861.0                                 0.15
# ...

# %% [markdown]
# #### ^We then replaced the names of the entries in the state variable therefore the entries will match with the other dataset; for example "California" is now "CA".

# %%
#step 3
df3=pd.merge(df, df1, on=["state", "date"])
df3
df3.drop(columns=['total_boosters', 'total_boosters_per_hundred'])
# Out:
#            date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0    2021-03-07    AL  10148.0          7963.0             -1         2185.0
# 1    2021-03-07    AZ  16328.0         14403.0              5         1925.0
# 2    2021-03-07    CA  54124.0          5251.0            258          735.0
# 3    2021-03-07    CO   5989.0          5251.0              3          735.0
# 4    2021-03-07    FL  32266.0         15598.0             66         2308.0
# ..          ...   ...      ...             ...            ...            ...
# 380  2021-01-12    CA  30513.0          4558.0            548          684.0
# 381  2021-01-12    CO   5242.0          4558.0             29          684.0
# 382  2021-01-12    FL  23585.0         10444.0            161         1218.0
# 383  2021-01-12    HI    309.0           309.0              0          179.0
# 384  2021-01-12    TX  30219.0          4833.0            286          644.0
#
# ...

# %% [markdown]
# #### ^We then use the command to merge the primary key "state" and "date" together. This gives a new table that has all the variables from both datasets. We also had to remove two columns from the table "total_boosters" and "total_boosters_per_hundred" since those variables didn't hold any entries.

# %%
total1=(df3.groupby("state")["total_vaccinations_per_hundred"].count())
total1
# Out:
# state
# AL    51
# AZ    50
# CA    51
# CO    50
# FL    49
# HI    49
# TX    49
# Name: total_vaccinations_per_hundred, dtype: int64

# %% [markdown]
# #### ^We then made another table that includes all the states that were renamed from the table to make a count table.

# %%
plt.pie(total1.values,labels=total1.index,autopct='%.0f%%')
plt.title("Total Vaccination Per Hundred")
plt.savefig("total.pdf",dpi=100)

# %% [markdown]
# #### ^We then went from that table to make a pie chart that shows the total number of vaccinations (by hundred) in percentage between the states. Noticable here California has the highest percentage by 1% higher whereas all the other states have the same.

# %%
g=sns.lmplot(x="death",y="total_distributed",hue="state",data=df3)
g.set(xlim=0,ylim=0,title="total distribution and fully vaccinated")

# %% [markdown]
# #### ^This scatterplot shows the relations between people fully vaccianted against total distribution (as in state vaccine distribution). The graph shows distinctly that there is a positive correlation where more distribution of vaccine are given between states gives higher number of people fully vaccinated.

# %%
g=sns.lmplot(x="people_vaccinated_per_hundred",y="people_fully_vaccinated",hue="state",data=df3)
g.set(xlim=0, ylim=0, title="number of death")

# %% [markdown]
# #### ^This scatterplot shows the relations between people fully vaccianted against people vaccinated (per hundred). This graph is meant to show that people who are vaccinated also tend to want to be fully vaccinated as well.

# %%
g=sns.lmplot(x="people_fully_vaccinated",y="positive",hue="state",data=df3)
g.set(xlim=0,ylim=0,title="people vaccinated and positive")

# %% [markdown]
# #### ^This is another scatterplot that shows people who are vaccinated and positive but are fully vaccinated as well. Although it's hard to interprete we can see that people who are positive from covid-19 are likely as well to get vaccinated fully.

# %%
g=sns.lmplot(x="people_fully_vaccinated",y="negative",hue="state",data=df3)
g.set(xlim=0,ylim=0,title="people vaccinated and negative")

# %% [markdown]
# #### ^ On the other hand this scatterplot shows people who are vaccinated and negative. This indicates that people who are tested negative still go to be fully vaccinated. We can see that Florida surprisingly has the highest count.

# %% [markdown]
# ## Endogeneity
#
# Our scatterplots are definitely not concretely evidental for a final conclusion of the correlation between the variables that are in the dataset to draw a clear understanding of the effects that covid-19 has on the states within the US and how the US has been combating with covid-19 vaccines. This can be drawn from the histogram where we used boolen method which in return showed missing data. Another issue was when we were cleaning the data of null values and had to use backwards filling method in addition to the command "fillna" which in certain situations can help a dataset operate better however with ours this could've led to dubplicate numbers filling in for the variable columns that have missing entries.

# %% [markdown]
# ## Conclusion
#
# Overall, we had a lot of data findings that were insightful and reflects the true correlations that have been searched upon on this research of covid-19's impact on the US. We were able to draw the states with the largest number of report both in vaccination distribution and covid-19 cases. There clear relations that states with higher cases of covid-19 leds to an increase in all areas of variables. One notable consistency to draw in as an outlier are the states Flordia and California. Whereas Florida shows that its has a consistent linear regression in all it's variable from covid-19 reports to vaccinations, California shows an exponential growth in it's variables.
#
# The graphs conducted from this project also solidifies or at the least draws the connection of the US's initial response to covid-19 where the state was met with protests and backlash on the government's attempt to facilitate and mandate the pandemic hence the initial higher increase that all states experience at the start until a slower more stable increase later on.
#
# Hopefully readers have found this research imformative and learn better on the operations used to build a simple yet insightful project using python jupyter notebook.

# %% [markdown]
# ## References
#
# CDC, C. for D. C. and P. (2022). Covid-19 testing: What you need to know. Centers for Disease Control and Prevention. Retrieved January 15, 2023, from https://www.cdc.gov/coronavirus/2019-ncov/symptoms-testing/testing.html#:~:text=Viral%20tests%20look%20for%20a,be%20recommended%20over%20the%20other.
#
#
# WHO, W. H. O. (2023). Coronavirus disease (COVID-19). World Health Organization. Retrieved January 15, 2023, from https://www.who.int/health-topics/coronavirus#tab=tab_1
#
#
# worldometer, worldometer. (2020, January 22). COVID-19 CORONAVIRUS PANDEMIC. Worldometer. Retrieved January 15, 2023, from https://www.worldometers.info/coronavirus/
#
# Centers for Disease Control and Prevention, C. D. C. (2022, November 1). Overview of covid-19 vaccines. Centers for Disease Control and Prevention. Retrieved January 19, 2023, from https://www.cdc.gov/coronavirus/2019-ncov/vaccines/different-vaccines/overview-COVID-19-vaccines.html
